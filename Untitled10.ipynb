# %%
### Fraud_Data.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np 
import datetime
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

# %%
fraud = pd.read_csv("C:\\Users\\julie\\OneDrive\\Bureau\\m1\\s\\SUPPORTS\\data\\Fraud_Data.csv ",  header=0)
fraud
# Out:
#         user_id          signup_time        purchase_time  purchase_value  \
# 0         22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1        333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2          1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3        150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4        221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
# ...         ...                  ...                  ...             ...
# 151107   345170  2015-01-27 03:03:34  2015-03-29 00:30:47              43
# 151108   274471  2015-05-15 17:43:29  2015-05-26 12:24:39              35
# 151109   368416  2015-03-03 23:07:31  2015-05-20 07:07:47              40
# 151110   207709  2015-07-09 20:06:07  2015-09-07 09:34:46              46
# 151111   138208  2015-06-10 07:02:20  2015-07-21 02:03:53              20
#
#             device_id  source browser sex  age    ip_address  class
# ...

# %%
ip = pd.read_csv("C:\\Users\\julie\\OneDrive\\Bureau\\m1\\s\\SUPPORTS\\data\\ip.csv ", header=0)
ip
# Out:
#         lower_bound_ip_address  upper_bound_ip_address    country
# 0                 1.677722e+07                16777471  Australia
# 1                 1.677747e+07                16777727      China
# 2                 1.677773e+07                16778239      China
# 3                 1.677824e+07                16779263  Australia
# 4                 1.677926e+07                16781311      China
# ...                        ...                     ...        ...
# 138841            3.758092e+09              3758093311  Hong Kong
# 138842            3.758093e+09              3758094335      India
# 138843            3.758095e+09              3758095871      China
# 138844            3.758096e+09              3758096127  Singapore
# 138845            3.758096e+09              3758096383  Australia
#
# [138846 rows x 3 columns]

# %%
# Ajout colonne country dataset fraud
df=pd.concat([ip, fraud.reindex(ip.index)], axis=1)
df['ip_address'].between(df['lower_bound_ip_address'],df['upper_bound_ip_address'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 138841    False
# 138842    False
# 138843    False
# 138844    False
# 138845    False
# Length: 138846, dtype: bool

# %%
country = len(fraud) * [0]

for ind, row in fraud.iterrows():
    test = ip[(ip['lower_bound_ip_address'] < row['ip_address']) & 
           (ip['upper_bound_ip_address'] > row['ip_address'])]['country']
    
    if len(test) == 1:
        country[ind] = test.values[0]   

fraud['country'] = country
fraud.to_csv('C:\\Users\\julie\\OneDrive\\Bureau\\m1\\s\\SUPPORTS\\data\\fraudData.csv')

# %%
fraudData = pd.read_csv("C:\\Users\\julie\\OneDrive\\Bureau\\m1\\s\\SUPPORTS\\data\\fraudData.csv ",  header=0)
fraudData
# Out:
#         Unnamed: 0  user_id          signup_time        purchase_time  \
# 0                0    22058  2015-02-24 22:55:49  2015-04-18 02:47:11
# 1                1   333320  2015-06-07 20:39:50  2015-06-08 01:38:54
# 2                2     1359  2015-01-01 18:52:44  2015-01-01 18:52:45
# 3                3   150084  2015-04-28 21:13:25  2015-05-04 13:54:50
# 4                4   221365  2015-07-21 07:09:52  2015-09-09 18:40:53
# ...            ...      ...                  ...                  ...
# 151107      151107   345170  2015-01-27 03:03:34  2015-03-29 00:30:47
# 151108      151108   274471  2015-05-15 17:43:29  2015-05-26 12:24:39
# 151109      151109   368416  2015-03-03 23:07:31  2015-05-20 07:07:47
# 151110      151110   207709  2015-07-09 20:06:07  2015-09-07 09:34:46
# 151111      151111   138208  2015-06-10 07:02:20  2015-07-21 02:03:53
#
#         purchase_value      device_id  source browser sex  age    ip_address  \
# ...

# %%
fraudData['signup_time'] = pd.to_datetime(fraudData['signup_time'])
fraudData['purchase_time'] = pd.to_datetime(fraudData['purchase_time'])
fraudData['diff_time'] = (fraudData['purchase_time'] - fraudData['signup_time'])/np.timedelta64(1, 's')
fraudData
# Out:
#         Unnamed: 0  user_id         signup_time       purchase_time  \
# 0                0    22058 2015-02-24 22:55:49 2015-04-18 02:47:11
# 1                1   333320 2015-06-07 20:39:50 2015-06-08 01:38:54
# 2                2     1359 2015-01-01 18:52:44 2015-01-01 18:52:45
# 3                3   150084 2015-04-28 21:13:25 2015-05-04 13:54:50
# 4                4   221365 2015-07-21 07:09:52 2015-09-09 18:40:53
# ...            ...      ...                 ...                 ...
# 151107      151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47
# 151108      151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39
# 151109      151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47
# 151110      151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46
# 151111      151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53
#
#         purchase_value      device_id  source browser sex  age    ip_address  \
# ...

# %%
device_count = fraudData.groupby('device_id')['user_id'].count()
device_user_count = device_count[fraudData['device_id']]
device_user_count = device_user_count.reset_index().drop('device_id', axis = 1)
fraudData['device_user_count'] = device_user_count

# %%
fraudData
# Out:
#         Unnamed: 0  user_id         signup_time       purchase_time  \
# 0                0    22058 2015-02-24 22:55:49 2015-04-18 02:47:11
# 1                1   333320 2015-06-07 20:39:50 2015-06-08 01:38:54
# 2                2     1359 2015-01-01 18:52:44 2015-01-01 18:52:45
# 3                3   150084 2015-04-28 21:13:25 2015-05-04 13:54:50
# 4                4   221365 2015-07-21 07:09:52 2015-09-09 18:40:53
# ...            ...      ...                 ...                 ...
# 151107      151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47
# 151108      151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39
# 151109      151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47
# 151110      151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46
# 151111      151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53
#
#         purchase_value      device_id  source browser sex  age    ip_address  \
# ...

# %%
ip_count = fraudData.groupby('ip_address')['user_id'].count()
ip_count = ip_count[fraudData['ip_address']].reset_index().drop('ip_address', axis = 1)
ip_count.columns = ['ip_count']
fraudData = pd.concat([fraudData, ip_count], axis = 1)
fraudData
# Out:
#         Unnamed: 0  user_id         signup_time       purchase_time  \
# 0                0    22058 2015-02-24 22:55:49 2015-04-18 02:47:11
# 1                1   333320 2015-06-07 20:39:50 2015-06-08 01:38:54
# 2                2     1359 2015-01-01 18:52:44 2015-01-01 18:52:45
# 3                3   150084 2015-04-28 21:13:25 2015-05-04 13:54:50
# 4                4   221365 2015-07-21 07:09:52 2015-09-09 18:40:53
# ...            ...      ...                 ...                 ...
# 151107      151107   345170 2015-01-27 03:03:34 2015-03-29 00:30:47
# 151108      151108   274471 2015-05-15 17:43:29 2015-05-26 12:24:39
# 151109      151109   368416 2015-03-03 23:07:31 2015-05-20 07:07:47
# 151110      151110   207709 2015-07-09 20:06:07 2015-09-07 09:34:46
# 151111      151111   138208 2015-06-10 07:02:20 2015-07-21 02:03:53
#
#         purchase_value      device_id  source browser sex  age    ip_address  \
# ...

# %%
fraudData['signup_day'] = fraudData['signup_time'].dt.dayofweek;
fraudData['signup_week'] = fraudData['signup_time'].dt.week;
fraudData['purchase_day'] = fraudData['purchase_time'].dt.dayofweek;
fraudData['purchase_week'] = fraudData['purchase_time'].dt.week;
fraudData
# Out:
# C:\Users\julie\AppData\Local\Temp/ipykernel_11300/103307062.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   fraudData['signup_week'] = fraudData['signup_time'].dt.week;
# C:\Users\julie\AppData\Local\Temp/ipykernel_11300/103307062.py:4: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   fraudData['purchase_week'] = fraudData['purchase_time'].dt.week;
#         Unnamed: 0  user_id         signup_time       purchase_time  \
# 0                0    22058 2015-02-24 22:55:49 2015-04-18 02:47:11
# 1                1   333320 2015-06-07 20:39:50 2015-06-08 01:38:54
# 2                2     1359 2015-01-01 18:52:44 2015-01-01 18:52:45
# 3                3   150084 2015-04-28 21:13:25 2015-05-04 13:54:50
# 4                4   221365 2015-07-21 07:09:52 2015-09-09 18:40:53
# ...

# %%
y = fraudData['class']
y
# Out:
# 0         0
# 1         0
# 2         1
# 3         0
# 4         0
#          ..
# 151107    1
# 151108    0
# 151109    0
# 151110    0
# 151111    0
# Name: class, Length: 151112, dtype: int64

# %%
fraudData = fraudData.drop(['user_id', 'signup_time','purchase_time','class'], axis = 1)
X = fraudData

lb = LabelEncoder()
X['device_id'] = lb.fit_transform(X['device_id'])
X['source'] = lb.fit_transform(X['source'])
X['browser'] = lb.fit_transform(X['browser'])
X['sex'] = lb.fit_transform(X['sex'])
X['country'] = lb.fit_transform(X['country'])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151112 entries, 0 to 151111
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         151112 non-null  int64
#  1   purchase_value     151112 non-null  int64
#  2   device_id          151112 non-null  int32
#  3   source             151112 non-null  int32
#  4   browser            151112 non-null  int32
#  5   sex                151112 non-null  int32
#  6   age                151112 non-null  int64
#  7   ip_address         151112 non-null  float64
#  8   country            151112 non-null  int32
#  9   diff_time          151112 non-null  float64
#  10  device_user_count  151112 non-null  int64
#  11  ip_count           151112 non-null  int64
#  12  signup_day         151112 non-null  int64
#  13  signup_week        151112 non-null  int64
#  14  purchase_day       151112 non-null  int64
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
y_train.shape
# Out:
# (90667,)

# %%
X_train.shape
# Out:
# (90667, 16)

# %%
X_test.shape
# Out:
# (60445, 16)

# %%
y_test.shape
# Out:
# (60445,)

# %%
pipeline = Pipeline(steps = [('clf', RandomForestClassifier(criterion = 'entropy'))])

# %%
clf_forest = RandomForestClassifier(n_estimators= 20, criterion = 'entropy', max_depth= 50, min_samples_leaf= 3,
                                    min_samples_split= 3, oob_score= True)

# %%
preds = clf_forest.predict(X_test)
preds
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11300/100429462.py in <module>
# ----> 1 preds = clf_forest.predict(X_test)
#       2 preds
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     795             The predicted classes.
#     796         """
# --> 797         proba = self.predict_proba(X)
#     798
#     799         if self.n_outputs_ == 1:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py in predict_proba(self, X)
#     835             classes corresponds to that in the attribute :term:`classes_`.
#     836         """
# --> 837         check_is_fitted(self)
#     838         # Check data
#     839         X = self._validate_X_predict(X)
#
# ...
